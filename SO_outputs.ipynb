# %% [markdown]
# # Load packages, read-in pre-processed data

# %%
conda list
# Out:
# # packages in environment at /opt/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2022.10                  py38_2
# _ipyw_jlab_nb_ext_conf    0.1.0            py38hecd8cb5_1
# affinegap                 1.12                     pypi_0    pypi
# aiohttp                   3.8.4                    pypi_0    pypi
# aiosignal                 1.3.1                    pypi_0    pypi
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda                  custom                   py38_1
# anaconda-client           1.11.2           py38hecd8cb5_0
# anaconda-navigator        2.3.0            py38hecd8cb5_0
# anyio                     3.5.0            py38hecd8cb5_0
# appdirs                   1.4.4              pyhd3eb1b0_0
# applaunchservices         0.3.0            py38hecd8cb5_0
# appnope                   0.1.2           py38hecd8cb5_1001
# appscript                 1.1.2            py38h9ed2024_0
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0           py38hca72f7f_0
# arrow                     1.2.3            py38hecd8cb5_1
# astroid                   2.14.2           py38hecd8cb5_0
# astropy                   5.1              py38h67323c0_0
# asttokens                 2.0.5              pyhd3eb1b0_0
# async-timeout             4.0.2                    pypi_0    pypi
# atomicwrites              1.4.0                      py_0
# attrs                     22.1.0           py38hecd8cb5_0
# autocorrect               2.6.1                    pypi_0    pypi
# automat                   20.2.0                     py_0
# autopep8                  1.6.0              pyhd3eb1b0_1
# babel                     2.11.0           py38hecd8cb5_0
# backcall                  0.2.0              pyhd3eb1b0_0
# backports                 1.1                pyhd3eb1b0_0
# backports.functools_lru_cache 1.6.4              pyhd3eb1b0_0
# backports.tempfile        1.0                pyhd3eb1b0_1
# backports.weakref         1.0.post1                  py_1
# bcrypt                    3.2.0            py38hca72f7f_1
# beautifulsoup4            4.12.2           py38hecd8cb5_0
# binaryornot               0.4.4              pyhd3eb1b0_1
# bio                       1.3.8                    pypi_0    pypi
# biopython                 1.79                     pypi_0    pypi
# biothings-client          0.2.6                    pypi_0    pypi
# bitarray                  2.5.1            py38hca72f7f_0
# bkcharts                  0.2              py38hecd8cb5_1
# black                     22.6.0           py38hecd8cb5_0
# blas                      1.0                         mkl
# bleach                    4.1.0              pyhd3eb1b0_0
# blis                      0.7.6                    pypi_0    pypi
# blosc                     1.21.3               hcec6c5f_0
# bokeh                     3.1.1                    pypi_0    pypi
# boltons                   23.0.0           py38hecd8cb5_0
# boto3                     1.24.28          py38hecd8cb5_0
# botocore                  1.27.59          py38hecd8cb5_0
# bottleneck                1.3.5            py38h67323c0_0
# brotli                    1.0.9                hca72f7f_7
# brotli-bin                1.0.9                hca72f7f_7
# brotlipy                  0.7.0           py38h9ed2024_1003
# brunsli                   0.1                  h23ab428_0
# bs4                       0.0.1                    pypi_0    pypi
# btrees                    4.9.2                    pypi_0    pypi
# bzip2                     1.0.8                h1de35cc_0
# c-ares                    1.19.0               h6c40b1e_0
# ca-certificates           2023.01.10           hecd8cb5_0
# cachetools                5.3.0                    pypi_0    pypi
# catalogue                 2.0.6                    pypi_0    pypi
# categorical-distance      1.9                      pypi_0    pypi
# cattrs                    22.2.0                   pypi_0    pypi
# certifi                   2022.12.7        py38hecd8cb5_0
# cffi                      1.15.1           py38h6c40b1e_3
# cfitsio                   3.470                hbd21bf8_7
# chardet                   3.0.4                    pypi_0    pypi
# charls                    2.2.0                h23ab428_0
# charset-normalizer        2.0.4              pyhd3eb1b0_0
# click                     8.1.3                    pypi_0    pypi
# click-plugins             1.1.1                    pypi_0    pypi
# cligj                     0.7.2                    pypi_0    pypi
# cloudpickle               2.2.1            py38hecd8cb5_0
# clyent                    1.2.2                    py38_1
# colorama                  0.4.3                    pypi_0    pypi
# colorcet                  3.0.1            py38hecd8cb5_0
# comm                      0.1.2            py38hecd8cb5_0
# conda                     23.3.1           py38hecd8cb5_0
# conda-build               3.21.4           py38hecd8cb5_0
# conda-content-trust       0.1.3            py38hecd8cb5_0
# conda-env                 2.6.0                         1
# conda-package-handling    2.0.2            py38hecd8cb5_0
# conda-package-streaming   0.7.0            py38hecd8cb5_0
# conda-repo-cli            1.0.41           py38hecd8cb5_0
# conda-token               0.4.0              pyhd3eb1b0_0
# conda-verify              3.4.2                      py_1
# constantly                15.1.0             pyh2b92418_0
# contourpy                 1.0.5            py38haf03e11_0
# cookiecutter              1.7.3              pyhd3eb1b0_0
# coverage                  7.2.3                    pypi_0    pypi
# cryptography              39.0.1           py38hf6deb26_0
# cssselect                 1.1.0              pyhd3eb1b0_0
# csvmatch                  1.20                     pypi_0    pypi
# curl                      7.88.1               h6c40b1e_0
# cycler                    0.11.0             pyhd3eb1b0_0
# cymem                     2.0.6                    pypi_0    pypi
# cython                    0.29.33          py38hcec6c5f_0
# cytoolz                   0.12.0           py38hca72f7f_0
# daal4py                   2023.1.1         py38h01d92e1_0
# dal                       2023.1.1         ha357a0b_48680
# dask                      2023.4.1         py38hecd8cb5_0
# dask-core                 2023.4.1         py38hecd8cb5_0
# datashader                0.14.4           py38hecd8cb5_0
# datashape                 0.5.4            py38hecd8cb5_1
# datetime                  4.7                      pypi_0    pypi
# datetime-distance         0.1.3                    pypi_0    pypi
# debugpy                   1.6.6                    pypi_0    pypi
# decorator                 5.1.1              pyhd3eb1b0_0
# dedupe                    1.10.0                   pypi_0    pypi
# dedupe-hcluster           0.3.9                    pypi_0    pypi
# dedupe-variable-datetime  0.1.5                    pypi_0    pypi
# defusedxml                0.7.1              pyhd3eb1b0_0
# dexplot                   0.1.4                    pypi_0    pypi
# diff-match-patch          20200713           pyhd3eb1b0_0
# dill                      0.3.6            py38hecd8cb5_0
# distributed               2023.4.1         py38hecd8cb5_0
# dnspython                 2.3.0                    pypi_0    pypi
# docker                    6.0.1                    pypi_0    pypi
# docstring-to-markdown     0.11             py38hecd8cb5_0
# docutils                  0.18.1           py38hecd8cb5_3
# doublemetaphone           0.1                      pypi_0    pypi
# duckduckgo-search         2.8.5                    pypi_0    pypi
# en-core-web-lg            3.2.0                    pypi_0    pypi
# en-core-web-sm            3.2.0                    pypi_0    pypi
# entrypoints               0.4              py38hecd8cb5_0
# et_xmlfile                1.1.0            py38hecd8cb5_0
# exceptiongroup            1.1.1                    pypi_0    pypi
# executing                 0.8.3              pyhd3eb1b0_0
# faker                     16.6.0                   pypi_0    pypi
# fastcluster               1.2.4                    pypi_0    pypi
# filelock                  3.9.0            py38hecd8cb5_0
# fiona                     1.9.1                    pypi_0    pypi
# fitter                    1.5.2                    pypi_0    pypi
# flake8                    6.0.0            py38hecd8cb5_0
# flask                     2.2.2            py38hecd8cb5_0
# flit-core                 3.6.0              pyhd3eb1b0_0
# fonttools                 4.25.0             pyhd3eb1b0_0
# freetype                  2.12.1               hd8bbffd_0
# frozenlist                1.3.3                    pypi_0    pypi
# fsspec                    2023.4.0         py38hecd8cb5_0
# future                    0.18.3           py38hecd8cb5_0
# fuzzy-pandas              0.1                      pypi_0    pypi
# fuzzywuzzy                0.18.0                   pypi_0    pypi
# gensim                    4.2.0                    pypi_0    pypi
# geojson-rewind            1.0.3                    pypi_0    pypi
# geomet                    1.0.0                    pypi_0    pypi
# geopandas                 0.12.2                   pypi_0    pypi
# gettext                   0.21.0               he85b6c0_1
# giflib                    5.2.1                h6c40b1e_3
# glib                      2.69.1               hfff2838_2
# glob2                     0.7                pyhd3eb1b0_0
# gmp                       6.2.1                he9d5cce_3
# gmpy2                     2.1.2            py38hd5de756_0
# google-api-core           2.11.0                   pypi_0    pypi
# google-api-python-client  2.77.0                   pypi_0    pypi
# google-auth               2.16.0                   pypi_0    pypi
# google-auth-httplib2      0.1.0                    pypi_0    pypi
# googleapis-common-protos  1.58.0                   pypi_0    pypi
# greenlet                  2.0.1            py38hcec6c5f_0
# gst-plugins-base          1.14.1               hcec6c5f_1
# gstreamer                 1.14.1               h6c40b1e_1
# gtts                      2.3.1                    pypi_0    pypi
# h5py                      3.7.0            py38h4a1dd59_0
# haversine                 2.5.1                    pypi_0    pypi
# hdf5                      1.10.6               h10fe05b_1
# heapdict                  1.0.1              pyhd3eb1b0_0
# highered                  0.2.1                    pypi_0    pypi
# holoviews                 1.15.4           py38hecd8cb5_0
# htmlmin                   0.1.12                   pypi_0    pypi
# httplib2                  0.21.0                   pypi_0    pypi
# hvplot                    0.8.2            py38hecd8cb5_0
# hyperlink                 21.0.0             pyhd3eb1b0_0
# icu                       58.2                 h0a44026_3
# idna                      2.8                      pypi_0    pypi
# imagecodecs               2021.8.26        py38h8a96914_2
# imagehash                 4.2.1                    pypi_0    pypi
# imageio                   2.26.0           py38hecd8cb5_0
# imagesize                 1.4.1            py38hecd8cb5_0
# importlib-metadata        6.0.0            py38hecd8cb5_0
# importlib_metadata        6.0.0                hd3eb1b0_0
# importlib_resources       5.2.0              pyhd3eb1b0_1
# incremental               21.3.0             pyhd3eb1b0_0
# inflection                0.5.1            py38hecd8cb5_0
# iniconfig                 1.1.1              pyhd3eb1b0_0
# intake                    0.6.8            py38hecd8cb5_0
# intel-openmp              2021.4.0          hecd8cb5_3538
# intervaltree              3.1.0              pyhd3eb1b0_0
# ipykernel                 6.21.1                   pypi_0    pypi
# ipython                   8.12.0           py38hecd8cb5_0
# ipython_genutils          0.2.0              pyhd3eb1b0_1
# ipywidgets                8.0.4            py38hecd8cb5_0
# isort                     5.9.3              pyhd3eb1b0_0
# itemadapter               0.3.0              pyhd3eb1b0_0
# itemloaders               1.0.4              pyhd3eb1b0_1
# itsdangerous              2.0.1              pyhd3eb1b0_0
# jaraco.classes            3.2.1              pyhd3eb1b0_0
# jdcal                     1.4.1              pyhd3eb1b0_0
# jedi                      0.18.1           py38hecd8cb5_1
# jellyfish                 0.7.2                    pypi_0    pypi
# jinja2                    3.1.2            py38hecd8cb5_0
# jinja2-time               0.2.0              pyhd3eb1b0_3
# jmespath                  0.10.0             pyhd3eb1b0_0
# joblib                    1.1.1            py38hecd8cb5_0
# jpeg                      9e                   h6c40b1e_1
# jq                        1.6               h9ed2024_1000
# json5                     0.9.6              pyhd3eb1b0_0
# jsonpatch                 1.32               pyhd3eb1b0_0
# jsonpointer               2.1                pyhd3eb1b0_0
# jsonschema                4.17.3           py38hecd8cb5_0
# jupyter                   1.0.0            py38hecd8cb5_8
# jupyter-client            7.4.1                    pypi_0    pypi
# jupyter-contrib-core      0.3.3                    pypi_0    pypi
# jupyter-contrib-nbextensions 0.5.1                    pypi_0    pypi
# jupyter-highlight-selected-word 0.2.0                    pypi_0    pypi
# jupyter-latex-envs        1.4.6                    pypi_0    pypi
# jupyter-nbextensions-configurator 0.4.1                    pypi_0    pypi
# jupyter_client            8.1.0            py38hecd8cb5_0
# jupyter_console           6.6.3            py38hecd8cb5_0
# jupyter_core              5.3.0            py38hecd8cb5_0
# jupyter_server            1.23.4           py38hecd8cb5_0
# jupyterlab                3.5.3            py38hecd8cb5_0
# jupyterlab_pygments       0.1.2                      py_0
# jupyterlab_server         2.22.0           py38hecd8cb5_0
# jupyterlab_widgets        3.0.5            py38hecd8cb5_0
# jxrlib                    1.1                  haf1e3a3_2
# keyring                   23.13.1          py38hecd8cb5_0
# kiwisolver                1.4.4            py38hcec6c5f_0
# kneed                     0.8.1                    pypi_0    pypi
# krb5                      1.19.4               hdba6334_0
# langcodes                 3.3.0                    pypi_0    pypi
# lazy-loader               0.2                      pypi_0    pypi
# lazy-object-proxy         1.6.0            py38h9ed2024_0
# lcms2                     2.12                 hf1fd2bf_0
# lerc                      3.0                  he9d5cce_0
# levenshtein-search        1.4.5                    pypi_0    pypi
# libaec                    1.0.4                hb1e8313_1
# libarchive                3.6.2                had00e1f_1
# libbrotlicommon           1.0.9                hca72f7f_7
# libbrotlidec              1.0.9                hca72f7f_7
# libbrotlienc              1.0.9                hca72f7f_7
# libclang                  14.0.6          default_hd95374b_1
# libclang13                14.0.6          default_habbcc1a_1
# libcurl                   7.88.1               ha585b31_0
# libcxx                    14.0.6               h9765a3e_0
# libdeflate                1.17                 hb664fd8_0
# libedit                   3.1.20221030         h6c40b1e_0
# libev                     4.33                 h9ed2024_1
# libffi                    3.4.4                hecd8cb5_0
# libgfortran               5.0.0           11_3_0_hecd8cb5_28
# libgfortran5              11.3.0              h9dfd629_28
# libiconv                  1.16                 hca72f7f_2
# libidn2                   2.3.2                h9ed2024_0
# liblief                   0.12.3               hcec6c5f_0
# libllvm11                 11.1.0               h46f1229_6
# libllvm12                 12.0.0               h9b2ccf5_3
# libllvm14                 14.0.6               h91fad77_3
# libnghttp2                1.46.0               ha29bfda_0
# libpng                    1.6.39               h6c40b1e_0
# libpq                     12.9                 h1c9f633_3
# libsodium                 1.0.18               h1de35cc_0
# libspatialindex           1.9.3                h23ab428_0
# libssh2                   1.10.0               h0a4fc7d_0
# libtiff                   4.5.0                hcec6c5f_2
# libunistring              0.9.10               h9ed2024_0
# libwebp                   1.2.4                hf6ce154_1
# libwebp-base              1.2.4                h6c40b1e_1
# libxml2                   2.10.3               h930c0e2_0
# libxslt                   1.1.37               h6d1eb0e_0
# libzopfli                 1.0.3                hb1e8313_0
# llvm-openmp               14.0.6               h0dcd299_0
# llvmlite                  0.39.1           py38h8346a28_0
# locket                    1.0.0            py38hecd8cb5_0
# loguru                    0.7.0                    pypi_0    pypi
# lxml                      4.9.2            py38h6c40b1e_0
# lz4-c                     1.9.4                hcec6c5f_0
# lzo                       2.10                 haf1e3a3_2
# markdown                  3.4.1            py38hecd8cb5_0
# markupsafe                2.1.1            py38hca72f7f_0
# matplotlib                3.7.1            py38hecd8cb5_1
# matplotlib-base           3.7.1            py38hda11e5a_1
# matplotlib-inline         0.1.6            py38hecd8cb5_0
# mccabe                    0.6.1                    pypi_0    pypi
# missingno                 0.5.1                    pypi_0    pypi
# mistune                   0.8.4           py38h1de35cc_1001
# mkl                       2021.4.0           hecd8cb5_637    anaconda
# mkl-service               2.4.0            py38h9ed2024_0
# mkl_fft                   1.3.1            py38h4ab4a9b_0
# mkl_random                1.2.2            py38hb2f4e1b_0
# mock                      4.0.3              pyhd3eb1b0_0
# more-itertools            8.12.0             pyhd3eb1b0_0
# mouseinfo                 0.1.3                    pypi_0    pypi
# mpc                       1.1.0                h6ef4df4_1
# mpfr                      4.0.2                h9066e36_1
# mpi                       1.0                       mpich
# mpich                     4.1.1                hc226d05_0
# mpmath                    1.2.1            py38hecd8cb5_0
# msal                      1.18.0                   pypi_0    pypi
# msgpack-python            1.0.3            py38haf03e11_0
# multidict                 6.0.4                    pypi_0    pypi
# multimethod               1.8                      pypi_0    pypi
# multipledispatch          0.6.0                    py38_0
# munch                     2.5.0                    pypi_0    pypi
# munkres                   1.1.4                      py_0
# murmurhash                1.0.6                    pypi_0    pypi
# mygene                    3.2.2                    pypi_0    pypi
# mypy_extensions           0.4.3            py38hecd8cb5_1
# natsort                   8.3.1                    pypi_0    pypi
# navigator-updater         0.3.0            py38hecd8cb5_0
# nbclassic                 0.5.5            py38hecd8cb5_0
# nbclient                  0.5.13           py38hecd8cb5_0
# nbconvert                 6.5.0                    pypi_0    pypi
# nbformat                  5.7.0            py38hecd8cb5_0
# ncurses                   6.4                  hcec6c5f_0
# nest-asyncio              1.5.6            py38hecd8cb5_0
# networkx                  2.8.4            py38hecd8cb5_1
# newsapi-python            0.2.6                    pypi_0    pypi
# nltk                      3.7                pyhd3eb1b0_0
# nose                      1.3.7           pyhd3eb1b0_1008
# notebook                  6.5.4            py38hecd8cb5_0
# notebook-shim             0.2.2            py38hecd8cb5_0
# nspr                      4.33                 he9d5cce_0
# nss                       3.74                 h47edf6a_0
# numba                     0.56.4           py38h07fba90_0
# numexpr                   2.8.4            py38he696674_0
# numpy                     1.22.4                   pypi_0    pypi
# numpy-base                1.23.5           py38h9cd3388_0
# numpydoc                  1.5.0            py38hecd8cb5_0
# office365-rest-python-client 2.3.12                   pypi_0    pypi
# olefile                   0.46               pyhd3eb1b0_0
# oniguruma                 6.9.7.1              h9ed2024_0
# openai                    0.27.2                   pypi_0    pypi
# opencv-python             4.5.5.62                 pypi_0    pypi
# openjpeg                  2.4.0                h66ea3da_0
# openpyxl                  3.0.10           py38hca72f7f_0
# openssl                   1.1.1t               hca72f7f_0
# orjson                    3.8.10                   pypi_0    pypi
# packaging                 23.0             py38hecd8cb5_0
# pandas                    1.3.5                    pypi_0    pypi
# pandas-flavor             0.5.0                    pypi_0    pypi
# pandas-profiling          3.2.0                    pypi_0    pypi
# pandocfilters             1.5.0              pyhd3eb1b0_0
# panel                     0.14.3           py38hecd8cb5_0
# param                     1.12.3           py38hecd8cb5_0
# parsel                    1.6.0            py38hecd8cb5_0
# parso                     0.8.3              pyhd3eb1b0_0
# partd                     1.2.0              pyhd3eb1b0_1
# pathlib                   1.0.1                    py38_2
# pathspec                  0.10.3           py38hecd8cb5_0
# pathy                     0.6.1                    pypi_0    pypi
# patsy                     0.5.3            py38hecd8cb5_0
# pcre                      8.45                 h23ab428_0
# pep8                      1.7.1            py38hecd8cb5_1
# persistent                4.7.0                    pypi_0    pypi
# pexpect                   4.8.0              pyhd3eb1b0_3
# phik                      0.12.2                   pypi_0    pypi
# pickleshare               0.7.5           pyhd3eb1b0_1003
# pillow                    9.4.0            py38hcec6c5f_0
# pinecone-client           2.2.1                    pypi_0    pypi
# pip                       23.1.2                   pypi_0    pypi
# pkginfo                   1.9.6            py38hecd8cb5_0
# pkgutil-resolve-name      1.3.10           py38hecd8cb5_0
# platformdirs              2.5.2            py38hecd8cb5_0
# playsound                 1.2.2                    pypi_0    pypi
# plotly                    5.9.0            py38hecd8cb5_0
# pluggy                    1.0.0            py38hecd8cb5_1
# ply                       3.11                     py38_0
# pooch                     1.4.0              pyhd3eb1b0_0
# poyo                      0.5.0              pyhd3eb1b0_0
# preshed                   3.0.6                    pypi_0    pypi
# progressbar2              4.0.0                    pypi_0    pypi
# prometheus_client         0.14.1           py38hecd8cb5_0
# prompt-toolkit            3.0.36           py38hecd8cb5_0
# prompt_toolkit            3.0.36               hd3eb1b0_0
# protego                   0.1.16                     py_0
# protobuf                  4.21.12                  pypi_0    pypi
# psutil                    5.9.0            py38hca72f7f_0
# ptyprocess                0.7.0              pyhd3eb1b0_2
# pure_eval                 0.2.2              pyhd3eb1b0_0
# py                        1.11.0             pyhd3eb1b0_0
# py-lief                   0.12.3           py38hcec6c5f_0
# pyasn1                    0.4.8              pyhd3eb1b0_0
# pyasn1-modules            0.2.8                      py_0
# pyautogui                 0.9.53                   pypi_0    pypi
# pycodestyle               2.10.0           py38hecd8cb5_0
# pycosat                   0.6.4            py38hca72f7f_0
# pycparser                 2.21               pyhd3eb1b0_0
# pyct                      0.5.0            py38hecd8cb5_0
# pycurl                    7.45.2           py38hdb2fb19_0
# pydantic                  1.8.2                    pypi_0    pypi
# pydispatcher              2.0.5            py38hecd8cb5_2
# pydocstyle                6.3.0            py38hecd8cb5_0
# pyerfa                    2.0.0            py38h9ed2024_0
# pyflakes                  3.0.1            py38hecd8cb5_0
# pygam                     0.8.0                    pypi_0    pypi
# pygbif                    0.6.2                    pypi_0    pypi
# pygetwindow               0.0.9                    pypi_0    pypi
# pygments                  2.15.1           py38hecd8cb5_0
# pyhacrf-datamade          0.2.6                    pypi_0    pypi
# pyhamcrest                2.0.2              pyhd3eb1b0_2
# pyjanitor                 0.23.1                   pypi_0    pypi
# pyjwt                     2.4.0            py38hecd8cb5_0
# pylbfgs                   0.2.0.14                 pypi_0    pypi
# pylint                    2.16.2           py38hecd8cb5_0
# pylint-venv               2.3.0            py38hecd8cb5_0
# pyls-spyder               0.4.0              pyhd3eb1b0_0
# pymsgbox                  1.0.9                    pypi_0    pypi
# pyobjc                    9.0.1                    pypi_0    pypi
# pyobjc-core               9.0.1                    pypi_0    pypi
# pyobjc-framework-accessibility 9.0.1                    pypi_0    pypi
# pyobjc-framework-accounts 9.0.1                    pypi_0    pypi
# pyobjc-framework-addressbook 9.0.1                    pypi_0    pypi
# pyobjc-framework-adservices 9.0.1                    pypi_0    pypi
# pyobjc-framework-adsupport 9.0.1                    pypi_0    pypi
# pyobjc-framework-applescriptkit 9.0.1                    pypi_0    pypi
# pyobjc-framework-applescriptobjc 9.0.1                    pypi_0    pypi
# pyobjc-framework-applicationservices 9.0.1                    pypi_0    pypi
# pyobjc-framework-apptrackingtransparency 9.0.1                    pypi_0    pypi
# pyobjc-framework-audiovideobridging 9.0.1                    pypi_0    pypi
# pyobjc-framework-authenticationservices 9.0.1                    pypi_0    pypi
# pyobjc-framework-automaticassessmentconfiguration 9.0.1                    pypi_0    pypi
# pyobjc-framework-automator 9.0.1                    pypi_0    pypi
# pyobjc-framework-avfoundation 9.0.1                    pypi_0    pypi
# pyobjc-framework-avkit    9.0.1                    pypi_0    pypi
# pyobjc-framework-avrouting 9.0.1                    pypi_0    pypi
# pyobjc-framework-backgroundassets 9.0.1                    pypi_0    pypi
# pyobjc-framework-businesschat 9.0.1                    pypi_0    pypi
# pyobjc-framework-calendarstore 9.0.1                    pypi_0    pypi
# pyobjc-framework-callkit  9.0.1                    pypi_0    pypi
# pyobjc-framework-cfnetwork 9.0.1                    pypi_0    pypi
# pyobjc-framework-classkit 9.0.1                    pypi_0    pypi
# pyobjc-framework-cloudkit 9.0.1                    pypi_0    pypi
# pyobjc-framework-cocoa    9.0.1                    pypi_0    pypi
# pyobjc-framework-collaboration 9.0.1                    pypi_0    pypi
# pyobjc-framework-colorsync 9.0.1                    pypi_0    pypi
# pyobjc-framework-contacts 9.0.1                    pypi_0    pypi
# pyobjc-framework-contactsui 9.0.1                    pypi_0    pypi
# pyobjc-framework-coreaudio 9.0.1                    pypi_0    pypi
# pyobjc-framework-coreaudiokit 9.0.1                    pypi_0    pypi
# pyobjc-framework-corebluetooth 9.0.1                    pypi_0    pypi
# pyobjc-framework-coredata 9.0.1                    pypi_0    pypi
# pyobjc-framework-corehaptics 9.0.1                    pypi_0    pypi
# pyobjc-framework-corelocation 9.0.1                    pypi_0    pypi
# pyobjc-framework-coremedia 9.0.1                    pypi_0    pypi
# pyobjc-framework-coremediaio 9.0.1                    pypi_0    pypi
# pyobjc-framework-coremidi 9.0.1                    pypi_0    pypi
# pyobjc-framework-coreml   9.0.1                    pypi_0    pypi
# pyobjc-framework-coremotion 9.0.1                    pypi_0    pypi
# pyobjc-framework-coreservices 9.0.1                    pypi_0    pypi
# pyobjc-framework-corespotlight 9.0.1                    pypi_0    pypi
# pyobjc-framework-coretext 9.0.1                    pypi_0    pypi
# pyobjc-framework-corewlan 9.0.1                    pypi_0    pypi
# pyobjc-framework-cryptotokenkit 9.0.1                    pypi_0    pypi
# pyobjc-framework-datadetection 9.0.1                    pypi_0    pypi
# pyobjc-framework-devicecheck 9.0.1                    pypi_0    pypi
# pyobjc-framework-dictionaryservices 9.0.1                    pypi_0    pypi
# pyobjc-framework-discrecording 9.0.1                    pypi_0    pypi
# pyobjc-framework-discrecordingui 9.0.1                    pypi_0    pypi
# pyobjc-framework-diskarbitration 9.0.1                    pypi_0    pypi
# pyobjc-framework-dvdplayback 9.0.1                    pypi_0    pypi
# pyobjc-framework-eventkit 9.0.1                    pypi_0    pypi
# pyobjc-framework-exceptionhandling 9.0.1                    pypi_0    pypi
# pyobjc-framework-executionpolicy 9.0.1                    pypi_0    pypi
# pyobjc-framework-extensionkit 9.0.1                    pypi_0    pypi
# pyobjc-framework-externalaccessory 9.0.1                    pypi_0    pypi
# pyobjc-framework-fileprovider 9.0.1                    pypi_0    pypi
# pyobjc-framework-fileproviderui 9.0.1                    pypi_0    pypi
# pyobjc-framework-findersync 9.0.1                    pypi_0    pypi
# pyobjc-framework-fsevents 9.0.1                    pypi_0    pypi
# pyobjc-framework-gamecenter 9.0.1                    pypi_0    pypi
# pyobjc-framework-gamecontroller 9.0.1                    pypi_0    pypi
# pyobjc-framework-gamekit  9.0.1                    pypi_0    pypi
# pyobjc-framework-gameplaykit 9.0.1                    pypi_0    pypi
# pyobjc-framework-healthkit 9.0.1                    pypi_0    pypi
# pyobjc-framework-imagecapturecore 9.0.1                    pypi_0    pypi
# pyobjc-framework-imserviceplugin 9.0.1                    pypi_0    pypi
# pyobjc-framework-inputmethodkit 9.0.1                    pypi_0    pypi
# pyobjc-framework-installerplugins 9.0.1                    pypi_0    pypi
# pyobjc-framework-instantmessage 9.0.1                    pypi_0    pypi
# pyobjc-framework-intents  9.0.1                    pypi_0    pypi
# pyobjc-framework-intentsui 9.0.1                    pypi_0    pypi
# pyobjc-framework-iosurface 9.0.1                    pypi_0    pypi
# pyobjc-framework-ituneslibrary 9.0.1                    pypi_0    pypi
# pyobjc-framework-kernelmanagement 9.0.1                    pypi_0    pypi
# pyobjc-framework-latentsemanticmapping 9.0.1                    pypi_0    pypi
# pyobjc-framework-launchservices 9.0.1                    pypi_0    pypi
# pyobjc-framework-libdispatch 9.0.1                    pypi_0    pypi
# pyobjc-framework-linkpresentation 9.0.1                    pypi_0    pypi
# pyobjc-framework-localauthentication 9.0.1                    pypi_0    pypi
# pyobjc-framework-localauthenticationembeddedui 9.0.1                    pypi_0    pypi
# pyobjc-framework-mailkit  9.0.1                    pypi_0    pypi
# pyobjc-framework-mapkit   9.0.1                    pypi_0    pypi
# pyobjc-framework-mediaaccessibility 9.0.1                    pypi_0    pypi
# pyobjc-framework-medialibrary 9.0.1                    pypi_0    pypi
# pyobjc-framework-mediaplayer 9.0.1                    pypi_0    pypi
# pyobjc-framework-mediatoolbox 9.0.1                    pypi_0    pypi
# pyobjc-framework-metal    9.0.1                    pypi_0    pypi
# pyobjc-framework-metalfx  9.0.1                    pypi_0    pypi
# pyobjc-framework-metalkit 9.0.1                    pypi_0    pypi
# pyobjc-framework-metalperformanceshaders 9.0.1                    pypi_0    pypi
# pyobjc-framework-metalperformanceshadersgraph 9.0.1                    pypi_0    pypi
# pyobjc-framework-metrickit 9.0.1                    pypi_0    pypi
# pyobjc-framework-mlcompute 9.0.1                    pypi_0    pypi
# pyobjc-framework-modelio  9.0.1                    pypi_0    pypi
# pyobjc-framework-multipeerconnectivity 9.0.1                    pypi_0    pypi
# pyobjc-framework-naturallanguage 9.0.1                    pypi_0    pypi
# pyobjc-framework-netfs    9.0.1                    pypi_0    pypi
# pyobjc-framework-network  9.0.1                    pypi_0    pypi
# pyobjc-framework-networkextension 9.0.1                    pypi_0    pypi
# pyobjc-framework-notificationcenter 9.0.1                    pypi_0    pypi
# pyobjc-framework-opendirectory 9.0.1                    pypi_0    pypi
# pyobjc-framework-osakit   9.0.1                    pypi_0    pypi
# pyobjc-framework-oslog    9.0.1                    pypi_0    pypi
# pyobjc-framework-passkit  9.0.1                    pypi_0    pypi
# pyobjc-framework-pencilkit 9.0.1                    pypi_0    pypi
# pyobjc-framework-photos   9.0.1                    pypi_0    pypi
# pyobjc-framework-photosui 9.0.1                    pypi_0    pypi
# pyobjc-framework-preferencepanes 9.0.1                    pypi_0    pypi
# pyobjc-framework-pushkit  9.0.1                    pypi_0    pypi
# pyobjc-framework-quartz   9.0.1                    pypi_0    pypi
# pyobjc-framework-quicklookthumbnailing 9.0.1                    pypi_0    pypi
# pyobjc-framework-replaykit 9.0.1                    pypi_0    pypi
# pyobjc-framework-safariservices 9.0.1                    pypi_0    pypi
# pyobjc-framework-safetykit 9.0.1                    pypi_0    pypi
# pyobjc-framework-scenekit 9.0.1                    pypi_0    pypi
# pyobjc-framework-screencapturekit 9.0.1                    pypi_0    pypi
# pyobjc-framework-screensaver 9.0.1                    pypi_0    pypi
# pyobjc-framework-screentime 9.0.1                    pypi_0    pypi
# pyobjc-framework-scriptingbridge 9.0.1                    pypi_0    pypi
# pyobjc-framework-searchkit 9.0.1                    pypi_0    pypi
# pyobjc-framework-security 9.0.1                    pypi_0    pypi
# pyobjc-framework-securityfoundation 9.0.1                    pypi_0    pypi
# pyobjc-framework-securityinterface 9.0.1                    pypi_0    pypi
# pyobjc-framework-servicemanagement 9.0.1                    pypi_0    pypi
# pyobjc-framework-sharedwithyou 9.0.1                    pypi_0    pypi
# pyobjc-framework-sharedwithyoucore 9.0.1                    pypi_0    pypi
# pyobjc-framework-shazamkit 9.0.1                    pypi_0    pypi
# pyobjc-framework-social   9.0.1                    pypi_0    pypi
# pyobjc-framework-soundanalysis 9.0.1                    pypi_0    pypi
# pyobjc-framework-speech   9.0.1                    pypi_0    pypi
# pyobjc-framework-spritekit 9.0.1                    pypi_0    pypi
# pyobjc-framework-storekit 9.0.1                    pypi_0    pypi
# pyobjc-framework-syncservices 9.0.1                    pypi_0    pypi
# pyobjc-framework-systemconfiguration 9.0.1                    pypi_0    pypi
# pyobjc-framework-systemextensions 9.0.1                    pypi_0    pypi
# pyobjc-framework-threadnetwork 9.0.1                    pypi_0    pypi
# pyobjc-framework-uniformtypeidentifiers 9.0.1                    pypi_0    pypi
# pyobjc-framework-usernotifications 9.0.1                    pypi_0    pypi
# pyobjc-framework-usernotificationsui 9.0.1                    pypi_0    pypi
# pyobjc-framework-videosubscriberaccount 9.0.1                    pypi_0    pypi
# pyobjc-framework-videotoolbox 9.0.1                    pypi_0    pypi
# pyobjc-framework-virtualization 9.0.1                    pypi_0    pypi
# pyobjc-framework-vision   9.0.1                    pypi_0    pypi
# pyobjc-framework-webkit   9.0.1                    pypi_0    pypi
# pyodbc                    4.0.34           py38he9d5cce_0
# pyopenssl                 23.0.0           py38hecd8cb5_0
# pyparsing                 3.0.9            py38hecd8cb5_0
# pyperclip                 1.8.2                    pypi_0    pypi
# pyproj                    3.4.1                    pypi_0    pypi
# pyqt                      5.15.7           py38he9d5cce_0
# pyqt5-sip                 12.11.0          py38he9d5cce_0
# pyqtwebengine             5.15.7           py38he9d5cce_0
# pyrect                    0.2.0                    pypi_0    pypi
# pyrsistent                0.18.0           py38hca72f7f_0
# pyscreeze                 0.1.28                   pypi_0    pypi
# pysocks                   1.7.1                    py38_1
# pytables                  3.7.0            py38h59775c6_1
# pytest                    7.1.2            py38hecd8cb5_0
# python                    3.8.16               h218abb5_3
# python-dateutil           2.8.2              pyhd3eb1b0_0
# python-dotenv             1.0.0                    pypi_0    pypi
# python-fastjsonschema     2.16.2           py38hecd8cb5_0
# python-levenshtein        0.12.2                   pypi_0    pypi
# python-libarchive-c       2.9                pyhd3eb1b0_1
# python-lmdb               1.4.1            py38hcec6c5f_0
# python-lsp-black          1.2.1            py38hecd8cb5_0
# python-lsp-jsonrpc        1.0.0              pyhd3eb1b0_0
# python-lsp-server         1.7.2            py38hecd8cb5_0
# python-slugify            5.0.2              pyhd3eb1b0_0
# python-snappy             0.6.1            py38hcec6c5f_0
# python-tvrage             0.1.4                    pypi_0    pypi
# python-utils              3.3.3                    pypi_0    pypi
# python.app                3                py38hca72f7f_0
# pytoolconfig              1.2.5            py38hecd8cb5_1
# pytweening                1.0.4                    pypi_0    pypi
# pytz                      2022.7           py38hecd8cb5_0
# pyviz_comms               2.0.2              pyhd3eb1b0_0
# pywavelets                1.4.1            py38h6c40b1e_0
# pyyaml                    6.0              py38h6c40b1e_1
# pyzmq                     25.0.2           py38hcec6c5f_0
# qdarkstyle                3.0.2              pyhd3eb1b0_0
# qstylizer                 0.2.2            py38hecd8cb5_0
# qt                        5.15.9               hecd8cb5_0
# qt-main                   5.15.2               h51e0635_8
# qt-webengine              5.15.9               h90a370e_4
# qtawesome                 1.2.2            py38hecd8cb5_0
# qtconsole                 5.4.2            py38hecd8cb5_0
# qtpy                      2.2.0            py38hecd8cb5_0
# qtwebkit                  5.212                hbfab81c_5
# queuelib                  1.5.0            py38hecd8cb5_0
# readability-lxml          0.8.1                    pypi_0    pypi
# readline                  8.2                  hca72f7f_0
# redis                     4.5.4                    pypi_0    pypi
# regex                     2022.7.9         py38hca72f7f_0
# requests                  2.21.0                   pypi_0    pypi
# requests-cache            1.0.0                    pypi_0    pypi
# requests-file             1.5.1              pyhd3eb1b0_0
# requests-toolbelt         0.9.1              pyhd3eb1b0_0
# ripgrep                   13.0.0               hc2228c6_0
# rlr                       2.4.6                    pypi_0    pypi
# rope                      1.7.0            py38hecd8cb5_0
# rsa                       4.9                      pypi_0    pypi
# rtree                     1.0.1            py38hecd8cb5_0
# ruamel.yaml               0.17.21          py38hca72f7f_0
# ruamel.yaml.clib          0.2.6            py38hca72f7f_1
# ruamel_yaml               0.17.21          py38hca72f7f_0
# rubicon-objc              0.4.5                    pypi_0    pypi
# s3transfer                0.6.0            py38hecd8cb5_0
# scikit-image              0.19.3           py38hcec6c5f_1
# scikit-learn              0.24.1                   pypi_0    pypi
# scikit-learn-intelex      2021.6.0         py38hecd8cb5_0
# scipy                     1.10.0           py38h91c6ef4_1
# scrapy                    2.8.0            py38hecd8cb5_0
# seaborn                   0.12.2           py38hecd8cb5_0
# send2trash                1.8.0              pyhd3eb1b0_1
# service_identity          18.1.0             pyhd3eb1b0_1
# setuptools                60.9.3                   pypi_0    pypi
# shapely                   2.0.1                    pypi_0    pypi
# sharepoint                0.4.2                    pypi_0    pypi
# sharepy                   2.0.0                    pypi_0    pypi
# sidetable                 0.9.0                    pypi_0    pypi
# simplecosine              1.2                      pypi_0    pypi
# sip                       6.6.2            py38he9d5cce_0
# six                       1.16.0             pyhd3eb1b0_1
# sklearn                   0.0                      pypi_0    pypi
# smart_open                5.2.1            py38hecd8cb5_0
# snappy                    1.1.9                he9d5cce_0
# sniffio                   1.2.0            py38hecd8cb5_1
# snowballstemmer           2.2.0              pyhd3eb1b0_0
# sortedcollections         2.1.0              pyhd3eb1b0_0
# sortedcontainers          2.4.0              pyhd3eb1b0_0
# soupsieve                 2.4              py38hecd8cb5_0
# spacy                     3.2.3                    pypi_0    pypi
# spacy-legacy              3.0.9                    pypi_0    pypi
# spacy-loggers             1.0.1                    pypi_0    pypi
# sphinx                    5.0.2            py38hecd8cb5_0
# sphinxcontrib-applehelp   1.0.2              pyhd3eb1b0_0
# sphinxcontrib-devhelp     1.0.2              pyhd3eb1b0_0
# sphinxcontrib-htmlhelp    2.0.0              pyhd3eb1b0_0
# sphinxcontrib-jsmath      1.0.1              pyhd3eb1b0_0
# sphinxcontrib-qthelp      1.0.3              pyhd3eb1b0_0
# sphinxcontrib-serializinghtml 1.1.5              pyhd3eb1b0_0
# spyder                    5.4.3            py38hecd8cb5_1
# spyder-kernels            2.4.3            py38hecd8cb5_0
# sqlalchemy                1.4.39           py38hca72f7f_0
# sqlite                    3.41.2               h6c40b1e_0
# srsly                     2.4.2                    pypi_0    pypi
# stack_data                0.2.0              pyhd3eb1b0_0
# statsmodels               0.13.5           py38hacda100_1
# striprtf                  0.0.21                   pypi_0    pypi
# sympy                     1.11.1           py38hecd8cb5_0
# tabulate                  0.8.10           py38hecd8cb5_0
# tangled-up-in-unicode     0.2.0                    pypi_0    pypi
# tbb                       2021.8.0             ha357a0b_0
# tbb4py                    2021.8.0         py38ha357a0b_0
# tblib                     1.7.0              pyhd3eb1b0_0
# tenacity                  8.2.2            py38hecd8cb5_0
# terminado                 0.17.1           py38hecd8cb5_0
# testpath                  0.6.0            py38hecd8cb5_0
# text-unidecode            1.3                pyhd3eb1b0_0
# textblob                  0.17.1                   pypi_0    pypi
# textdistance              4.2.1              pyhd3eb1b0_0
# thinc                     8.0.13                   pypi_0    pypi
# threadpoolctl             2.2.0              pyh0d69192_0
# three-merge               0.1.1              pyhd3eb1b0_0
# tifffile                  2021.7.2           pyhd3eb1b0_2
# tiktoken                  0.3.3                    pypi_0    pypi
# tinycss2                  1.1.1                    pypi_0    pypi
# tk                        8.6.12               h5d9f67b_0
# tldextract                3.2.0              pyhd3eb1b0_0
# toml                      0.10.2             pyhd3eb1b0_0
# tomli                     2.0.1            py38hecd8cb5_0
# tomlkit                   0.11.1           py38hecd8cb5_0
# toolz                     0.12.0           py38hecd8cb5_0
# tornado                   6.2              py38hca72f7f_0
# tqdm                      4.63.0                   pypi_0    pypi
# traitlets                 5.7.1            py38hecd8cb5_0
# twisted                   22.2.0           py38hca72f7f_1
# typer                     0.4.0                    pypi_0    pypi
# typing-extensions         4.5.0            py38hecd8cb5_0
# typing_extensions         4.5.0            py38hecd8cb5_0
# ujson                     5.4.0            py38he9d5cce_0
# unidecode                 1.1.1                    pypi_0    pypi
# unixodbc                  2.3.11               hb456775_0
# uritemplate               4.1.1                    pypi_0    pypi
# url-normalize             1.4.3                    pypi_0    pypi
# urllib3                   1.24.3                   pypi_0    pypi
# utils                     1.0.1                    pypi_0    pypi
# visions                   0.7.4                    pypi_0    pypi
# voila                     0.4.0                    pypi_0    pypi
# w3lib                     1.21.0             pyhd3eb1b0_0
# wasabi                    0.9.0                    pypi_0    pypi
# watchdog                  2.1.6            py38h999c104_0
# wcwidth                   0.2.5              pyhd3eb1b0_0
# webencodings              0.5.1                    py38_1
# websocket-client          0.58.0           py38hecd8cb5_4
# websockets                10.3                     pypi_0    pypi
# werkzeug                  2.2.3            py38hecd8cb5_0
# wget                      1.21.3               h6dfd666_0
# whatthepatch              1.0.2            py38hecd8cb5_0
# wheel                     0.37.1                   pypi_0    pypi
# widgetsnbextension        4.0.5            py38hecd8cb5_0
# wrapt                     1.14.1           py38hca72f7f_0
# wurlitzer                 3.0.2            py38hecd8cb5_0
# xarray                    2022.11.0        py38hecd8cb5_0
# xlrd                      2.0.1              pyhd3eb1b0_0
# xlsxwriter                3.0.3              pyhd3eb1b0_0
# xlwings                   0.29.1           py38hecd8cb5_0
# xyzservices               2023.2.0                 pypi_0    pypi
# xz                        5.4.2                h6c40b1e_0
# yaml                      0.2.5                haf1e3a3_0
# yapf                      0.31.0             pyhd3eb1b0_0
# yarl                      1.8.2                    pypi_0    pypi
# yellowbrick               1.5                      pypi_0    pypi
# zeromq                    4.3.4                h23ab428_0
# zfp                       0.5.5                he9d5cce_6
# zict                      2.2.0            py38hecd8cb5_0
# zipp                      3.11.0           py38hecd8cb5_0
# zlib                      1.2.13               h4dc903c_0
# zope                      1.0                      py38_1
# zope-index                5.1.0                    pypi_0    pypi
# zope.interface            5.4.0            py38h9ed2024_0
# zstandard                 0.19.0           py38h6c40b1e_0
# zstd                      1.5.5                hc035e20_0
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import relevant packages

import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

from bokeh.io import show, curdoc, output_notebook
from bokeh.layouts import column
from bokeh.models import (
    ColumnDataSource,
    Label,
    LabelSet,
    CheckboxGroup,
    CustomJS,
    Button,
)
from bokeh.models.annotations import LabelSet
from bokeh.palettes import Category10
from bokeh.plotting import figure

import numpy as np

# %%
#  Read-in the pre-processed data

# df without urban-rural classification
df = pd.read_csv('/Users/loucap/Documents/GitWork/InteractiveGender/Data/cleaned_lang_SO.csv')

# Let's take a quick glance

df.head()
# Out:
#      LA_code               LA_name  SO_code SO_categories  Observation_x  \
# 0  E06000001            Hartlepool        5  Not answered           4554
# 1  E06000002         Middlesbrough        5  Not answered           8298
# 2  E06000003  Redcar and Cleveland        5  Not answered           7046
# 3  E06000004      Stockton-on-Tees        5  Not answered           9268
# 4  E06000005            Darlington        5  Not answered           5010
#
#    Percentages  Non-response_rate    region_x  Observation_y  \
# 0     6.097528           6.097528  North East           1875
# 1     7.282908           7.282908  North East          10510
# 2     6.271920           6.271920  North East           1460
# 3     5.865452           5.865452  North East           5674
# 4     5.686332           5.686332  North East           4403
#
#    Observation_total  Percentage    region_y  Shannon_idx
# 0              92337    2.030605  North East     0.931876
# 1             143923    7.302516  North East     1.181237
# 2             136533    1.069339  North East     0.831589
# 3             196603    2.886019  North East     1.001650
# 4             107800    4.084416  North East     0.966864

# %%
# df with urban-rural classification
df2 = pd.read_csv('/Users/loucap/Documents/GitWork/InteractiveGender/Data/urban_rural_SO.csv')

# Let's take a quick glance
# IMPORTANT: we only have urb_rural classification for ENGLISH LA's
df2.head()
# Out:
#      LA_code               LA_name  SO_code SO_categories  Observation_x  \
# 0  E06000001            Hartlepool        5  Not answered           4554
# 1  E06000002         Middlesbrough        5  Not answered           8298
# 2  E06000003  Redcar and Cleveland        5  Not answered           7046
# 3  E06000004      Stockton-on-Tees        5  Not answered           9268
# 4  E06000005            Darlington        5  Not answered           5010
#
#    Percentages  Non-response_rate    region_x  Observation_y  \
# 0     6.097528           6.097528  North East           1875
# 1     7.282908           7.282908  North East          10510
# 2     6.271920           6.271920  North East           1460
# 3     5.865452           5.865452  North East           5674
# 4     5.686332           5.686332  North East           4403
#
#    Observation_total  Percentage    region_y                       Urb_Rur
# 0              92337    2.030605  North East           Predominantly Urban
# 1             143923    7.302516  North East           Predominantly Urban
# 2             136533    1.069339  North East  Urban with Significant Rural
# 3             196603    2.886019  North East           Predominantly Urban
# 4             107800    4.084416  North East           Predominantly Urban

# %% [markdown]
# # Interactive scatterplots
#
# ## Shows the relationship between the % of Non-English speakers and % of Non-response for our 331 Local Authorities in England and Wales.
#
# ### COLOURED BY REGION

# %%
df['Urb_Rur'] = df2['Urb_Rur']

# %%
df
# Out:
#        LA_code               LA_name  SO_code SO_categories  Observation_x  \
# 0    E06000001            Hartlepool        5  Not answered           4554
# 1    E06000002         Middlesbrough        5  Not answered           8298
# 2    E06000003  Redcar and Cleveland        5  Not answered           7046
# 3    E06000004      Stockton-on-Tees        5  Not answered           9268
# 4    E06000005            Darlington        5  Not answered           5010
# ..         ...                   ...      ...           ...            ...
# 326  W06000020               Torfaen        5  Not answered           5233
# 327  W06000021         Monmouthshire        5  Not answered           5423
# 328  W06000022               Newport        5  Not answered           8721
# 329  W06000023                 Powys        5  Not answered           9832
# 330  W06000024        Merthyr Tydfil        5  Not answered           2910
#
#      Percentages  Non-response_rate    region_x  Observation_y  \
# 0       6.097528           6.097528  North East           1875
# 1       7.282908           7.282908  North East          10510
# 2       6.271920           6.271920  North East           1460
# 3       5.865452           5.865452  North East           5674
# 4       5.686332           5.686332  North East           4403
# ..           ...                ...         ...            ...
# 326     6.966837           6.966837       Wales           1318
# 327     6.931237           6.931237       Wales           1457
# 328     6.844133           6.844133       Wales          10035
# 329     8.736837           8.736837       Wales           2496
# 330     6.103572           6.103572       Wales           2176
#
#      Observation_total  Percentage    region_y  Shannon_idx  \
# 0                92337    2.030605  North East     0.931876
# 1               143923    7.302516  North East     1.181237
# 2               136533    1.069339  North East     0.831589
# 3               196603    2.886019  North East     1.001650
# 4               107800    4.084416  North East     0.966864
# ..                 ...         ...         ...          ...
# 326              92273    1.428370       Wales     0.850490
# 327              92955    1.567425       Wales     0.855804
# 328             159590    6.287988       Wales     1.085068
# 329             133173    1.874254       Wales     0.861874
# 330              58842    3.698039       Wales     0.842286
#
#                           Urb_Rur
# 0             Predominantly Urban
# 1             Predominantly Urban
# 2    Urban with Significant Rural
# 3             Predominantly Urban
# 4             Predominantly Urban
# ..                            ...
# 326           Welsh/not specified
# 327           Welsh/not specified
# 328           Welsh/not specified
# 329           Welsh/not specified
# 330           Welsh/not specified
#
# [331 rows x 14 columns]

# %%
df.Urb_Rur.unique()
# Out:
# array(['Predominantly Urban', 'Urban with Significant Rural',
#        'Predominantly Rural', 'Not specified', 'Welsh/not specified'],
#       dtype=object)

# %%
import pandas as pd
from bokeh.layouts import column
from bokeh.models import ColumnDataSource, Select
from bokeh.plotting import figure, curdoc
from bokeh.palettes import Category10
from bokeh.transform import factor_cmap
from bokeh.models import ColorBar, BasicTicker, PrintfTickFormatter, LogColorMapper


output_notebook()

# Prepare data sources
df['Urb_Rur'] = df['Urb_Rur'].astype(str)
source = ColumnDataSource(df)


# Define tooltips
tool = [
    ("index", "$index"),
    ("(x,y)", "($x, $y)"),
    ("name", "@LA_name"),
]

p0 = figure(title = "Relationship between Non-response Rate and Non-English Speakers", x_axis_label = "Percentage of Non-English Speakers",
           y_axis_label = "Non-response rate", tooltips = tool)

p0.scatter("Percentage", "Non-response_rate", source=source, fill_alpha=0.5, size=10)

# Plot 1 (By Region)
p1 = figure(title="Relationship between Non-response Rate and Non-English Speakers",
            x_axis_label="Percentage of Non-English Speakers",
            y_axis_label="Non-response Rate",
            tooltips=tool)

for region, color in zip(df.region_x.unique(), Category10[10]):
    b = df[df.region_x == region]
    p1.circle(x='Percentage', y='Non-response_rate', size=10, alpha=0.5, color=color,
              legend_label=region, muted_color=color, muted_alpha=0.1, source=ColumnDataSource(b))

p1.legend.location = "bottom_right"
p1.legend.click_policy = "hide"
p1.legend.title = "Regions"

# Plot 2 (Urban vs Rural)
p_2 = figure(title="Relationship between Non-response Rate and Non-English Speakers",
            x_axis_label="Percentage of Non-English Speakers",
            y_axis_label="Non-response Rate",
            tooltips=tool)

urban_rural_sources = {}  # Create a dictionary to store the ColumnDataSource objects
for urb_rur in df.Urb_Rur.unique():
    urban_rural_sources[urb_rur] = ColumnDataSource(df[df.Urb_Rur == urb_rur])

for urb_rur, color in zip(df.Urb_Rur.unique(), Category10[10]):
    p_2.circle(x='Percentage', y='Non-response_rate', size=10, alpha=0.5, color=color,
              legend_label=urb_rur, muted_color=color, muted_alpha=0.1, source=urban_rural_sources[urb_rur])

p_2.legend.location = "bottom_right"
p_2.legend.click_policy = "hide"
p_2.legend.title = "Urban-Rural"



# Plot 3 (Shannon Index)
color_map = LogColorMapper(palette="Viridis256", low=df.Shannon_idx.min(), high=df.Shannon_idx.max())

p3 = figure(title="Relationship between Non-response Rate and Non-English Speakers",
            x_axis_label="Non-response Rate",
            y_axis_label="Percentage of Non-English Speakers",
            tooltips=tool)

p3.scatter("Percentage", "Non-response_rate", source=source, fill_alpha=0.5, size=10,
           color={'field': 'Shannon_idx', 'transform': color_map})

color_bar = ColorBar(color_mapper=color_map,
                     title='Shannon Index',
                     ticker=BasicTicker(desired_num_ticks=5),
                     formatter=PrintfTickFormatter(format='%.2f'))

p3.add_layout(color_bar, 'right')

# Dropdown menu
dropdown = Select(title="Color By:", value="None", options=["Default", "Region", "Urban", "Shannon Index"])

# Define the update function
def update_scatterplots(attr, old, new):
    if dropdown.value == "Default":
        p0.visible = True
        p1.visible = False
        p_2.visible = False
        p3.visible = False
    elif dropdown.value == "Region":
        p0.visible = False
        p1.visible = True
        p_2.visible = False
        p3.visible = False
    elif dropdown.value == "Urban":
        p0.visible = False
        p1.visible = False
        p_2.visible = True
        p3.visible = False
    elif dropdown.value == "Shannon Index":
        p0.visible = False
        p1.visible = False
        p_2.visible = False
        p3.visible = True

# Set initial visibility
p0.visible = True
p1.visible = False
p_2.visible = False
p3.visible = False

# Add the callback to the dropdown menu
dropdown.on_change('value', update_scatterplots)

# Create a layout with the dropdown menu and the scatterplots
layout = column(dropdown, p0, p1, p_2, p3)

# Add the layout to the document
curdoc().add_root(layout)

# show(p2)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# Read-in pre-processed data for religion

rel = pd.read_csv('/Users/loucap/Documents/GitWork/InteractiveGender/Data/cleaned_religion_SO.csv')

# %%
rel
# Out:
#        LA_code               LA_name  SO_code SO_categories  Religion_code  \
# 0    E06000001            Hartlepool        5  Not answered              1
# 1    E06000002         Middlesbrough        5  Not answered              1
# 2    E06000003  Redcar and Cleveland        5  Not answered              1
# 3    E06000004      Stockton-on-Tees        5  Not answered              1
# 4    E06000005            Darlington        5  Not answered              1
# ..         ...                   ...      ...           ...            ...
# 326  W06000020               Torfaen        5  Not answered              1
# 327  W06000021         Monmouthshire        5  Not answered              1
# 328  W06000022               Newport        5  Not answered              1
# 329  W06000023                 Powys        5  Not answered              1
# 330  W06000024        Merthyr Tydfil        5  Not answered              1
#
#     Religion_categories  Observation  Group_Percentages_No religion  \
# 0           No religion         1139                           1.61
# 1           No religion         1751                           1.63
# 2           No religion         1824                           1.71
# 3           No religion         2249                           1.50
# 4           No religion         1256                           1.50
# ..                  ...          ...                            ...
# 326         No religion         1495                           2.12
# 327         No religion         1458                           1.98
# 328         No religion         2386                           1.98
# 329         No religion         2541                           2.43
# 330         No religion          869                           1.92
#
#      Total_LA_counts  No religion_%  ...  Observation_Hindu  \
# 0              70898          38.76  ...                 23
# 1             107747          35.98  ...                 86
# 2             106453          38.58  ...                  9
# 3             150094          38.48  ...                 26
# 4              83761          39.32  ...                 21
# ..               ...            ...  ...                ...
# 326            70598          50.32  ...                 12
# 327            73676          43.34  ...                 14
# 328           120275          43.65  ...                 42
# 329           104686          42.47  ...                 25
# 330            45250          52.16  ...                  7
#
#     Group_Percentages_Hindu  Total_LA_counts_Hindu  Hindu_%  \
# 0                      0.03                  70898     0.23
# 1                      0.08                 107747     1.20
# 2                      0.01                 106453     0.10
# 3                      0.02                 150094     0.41
# 4                      0.03                  83761     0.41
# ..                      ...                    ...      ...
# 326                    0.02                  70598     0.32
# 327                    0.02                  73676     0.22
# 328                    0.03                 120275     0.48
# 329                    0.02                 104686     0.23
# 330                    0.02                  45250     0.22
#
#      Religion_code_Sikh  Religion_categories_Sikh  Observation_Sikh  \
# 0                     7                      Sikh                15
# 1                     7                      Sikh                33
# 2                     7                      Sikh                 4
# 3                     7                      Sikh                25
# 4                     7                      Sikh                30
# ..                  ...                       ...               ...
# 326                   7                      Sikh                 7
# 327                   7                      Sikh                 6
# 328                   7                      Sikh                11
# 329                   7                      Sikh                 3
# 330                   7                      Sikh                 4
#
#     Group_Percentages_Sikh  Total_LA_counts_Sikh  Sikh_%
# 0                     0.02                 70898    0.19
# 1                     0.03                107747    0.41
# 2                     0.00                106453    0.04
# 3                     0.02                150094    0.40
# 4                     0.04                 83761    0.40
# ..                     ...                   ...     ...
# 326                   0.01                 70598    0.06
# 327                   0.01                 73676    0.11
# 328                   0.01                120275    0.27
# 329                   0.00                104686    0.05
# 330                   0.01                 45250    0.12
#
# [331 rows x 52 columns]

# %%
rel.columns
# Out:
# Index(['LA_code', 'LA_name', 'SO_code', 'SO_categories', 'Religion_code',
#        'Religion_categories', 'Observation', 'Group_Percentages_No religion',
#        'Total_LA_counts', 'No religion_%', 'Religion_code_Christian',
#        'Religion_categories_Christian', 'Observation_Christian',
#        'Group_Percentages_Christian', 'Total_LA_counts_Christian',
#        'Christian_%', 'Religion_code_Muslim', 'Religion_categories_Muslim',
#        'Observation_Muslim', 'Group_Percentages_Muslim',
#        'Total_LA_counts_Muslim', 'Muslim_%', 'Religion_code_Other',
#        'Religion_categories_Other', 'Observation_Other',
#        'Group_Percentages_Other', 'Total_LA_counts_Other', 'Other_%',
#        'Religion_code_Buddhist', 'Religion_categories_Buddhist',
#        'Observation_Buddhist', 'Group_Percentages_Buddhist',
#        'Total_LA_counts_Buddhist', 'Buddhist_%', 'Religion_code_Jewish',
#        'Religion_categories_Jewish', 'Observation_Jewish',
#        'Group_Percentages_Jewish', 'Total_LA_counts_Jewish', 'Jewish_%',
#        'Religion_code_Hindu', 'Religion_categories_Hindu', 'Observation_Hindu',
#        'Group_Percentages_Hindu', 'Total_LA_counts_Hindu', 'Hindu_%',
#        'Religion_code_Sikh', 'Religion_categories_Sikh', 'Observation_Sikh',
#        'Group_Percentages_Sikh', 'Total_LA_counts_Sikh', 'Sikh_%'],
#       dtype='object')

# %%
# Read-in totals and non-response by religion

totals = pd.read_csv('/Users/loucap/Documents/GitWork/InteractiveGender/Data/gen_totals_SO.csv')

# %%
totals.head()
# Out:
#   Religion_categories  Observation  Percent_of_survey_respondents
# 0            Buddhist       245514                           0.54
# 1           Christian     23656564                          51.78
# 2               Hindu       823132                           1.80
# 3              Jewish       213617                           0.47
# 4              Muslim      2664709                           5.83

# %%
totals = totals.sort_values(by = "Percent_of_survey_respondents", ascending = False)

# %%
# Read-in Non-response table

nr_totals = pd.read_csv('/Users/loucap/Documents/GitWork/InteractiveGender/Data/nr_totals_SO.csv')

nr_totals.head()
# Out:
#   Religion_categories  Observation  Non_response_rate  \
# 0            Buddhist        18331               7.47
# 1           Christian      1054454               4.46
# 2               Hindu        61226               7.44
# 3              Jewish        18054               8.45
# 4              Muslim       217981               8.18
#
#    Contribution_to_overall_non_response_rate
# 0                                       0.82
# 1                                      47.25
# 2                                       2.74
# 3                                       0.81
# 4                                       9.77

# %%
nr_totals = nr_totals.sort_values(by = "Contribution_to_overall_non_response_rate", ascending = False)

# %%
import pandas as pd
from bokeh.layouts import column, row
from bokeh.models import ColumnDataSource, Select, HTMLTemplateFormatter
from bokeh.models.widgets import DataTable, TableColumn, Div
from bokeh.plotting import figure, show, curdoc
from bokeh.io import output_notebook

# Custom cell formatter
template = """
<% if (Religion_categories == selected_religion) { %>
    <span style="color: red; font-weight: bold"><%= value %></span>
<% } else { %>
    <span style="font-weight: bold"><%= value %></span>
<% } %>
"""

def create_formatter(selected_religion):
    formatter = HTMLTemplateFormatter(template=template.replace("selected_religion", f"'{selected_religion}'"))
    return formatter

# Create DataTable for layout1
source1 = ColumnDataSource(totals)

columns1 = [
    TableColumn(field="Religion_categories", title="Religion", formatter=create_formatter('Christian')),
    TableColumn(field="Observation", title="Observation", formatter=create_formatter('Christian')),
    TableColumn(field="Percent_of_survey_respondents", title="% of respondents", formatter=create_formatter('Christian')),
]

heading1 = Div(text="<h1>Totals</h1>", width=300)

data_table1 = DataTable(source=source1, columns=columns1, editable=False, width=500, index_position=None)

layout1 = column(heading1, data_table1)

# Create DataTable for layout2
source2 = ColumnDataSource(nr_totals)

columns2 = [
    TableColumn(field="Religion_categories", title="Religion", formatter=create_formatter('Christian')),
    TableColumn(field="Observation", title="Observation", formatter=create_formatter('Christian')),
    TableColumn(field="Non_response_rate", title="Non response rate", formatter=create_formatter('Christian')),
    TableColumn(field="Contribution_to_overall_non_response_rate", title="% of total Non-response rate", formatter=create_formatter('Christian')),
]

heading2 = Div(text="<h1>Non-response rates</h1>", width=300)

data_table2 = DataTable(source=source2, columns=columns2, editable=False, width=700, index_position=None)

layout2 = column(heading2, data_table2)

# Scatter plot
output_notebook()

# Prepare data
rel['selected_religion'] = rel['Christian_%']  # Default religion
rel['selected_percentages'] = rel['Group_Percentages_Christian']

source = ColumnDataSource(rel)

# Define tooltips
tool = [
    ("index", "$index"),
    ("(x,y)", "($x, $y)"),
    ("name", "@LA_name"),
]

# Create figure
p4 = figure(title="Relationship between % of religious group in given LA, and their non-response rate",
            y_axis_label="Non-response Rate", x_axis_label="Percentage of religious group in given LA", tooltips=tool)

# Scatter plot
p4.scatter("selected_religion", "selected_percentages", source=source, fill_alpha=0.5, size=10)

def update_highlighted_rows(selected_religion):
    formatter = create_formatter(selected_religion)
    for col in columns1:
        col.formatter = formatter
    for col in columns2:
        col.formatter = formatter
    data_table1.columns = columns1
    data_table2.columns = columns2

# Define callback for updating data source

def update_plot(attr, old, new):
    selected_religion = select_religion.value
    rel['selected_religion'] = rel[f'{selected_religion}_%']
    rel['selected_percentages'] = rel[f'Group_Percentages_{selected_religion}']
    source.data = source.from_df(rel)
    update_highlighted_rows(selected_religion)

# Create select widget
options = ['Christian', 'No religion', 'Muslim', 'Jewish', 'Buddhist', 'Hindu', 'Sikh', 'Other']
select_religion = Select(title="Religious Group:", value='Christian', options=options)
select_religion.on_change('value', update_plot)

# Initial update of the highlighted rows
update_highlighted_rows(select_religion.value)

# Layout
layout = column(select_religion, p4)
l = row(layout1, layout2)

# Show plot
curdoc().add_root(column(layout, l))
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1642">Loading BokehJS ...</span>
#     </div>
